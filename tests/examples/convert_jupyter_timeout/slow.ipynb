# %% [markdown]
# # Slow notebook
#
# The following cell takes longer than the timeout of the step,
# but it is tagged `stepup-no-timeout`.

# %%
import time

time.sleep(3)

# %%
with open("result.txt", "w") as fh:
    print("done", file=fh)
